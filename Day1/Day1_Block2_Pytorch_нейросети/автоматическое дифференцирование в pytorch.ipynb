# %%
import torch

# %%
torch.ones(3)
# Out:
# tensor([1., 1., 1.])

# %%
x = torch.tensor([1,2,3.], requires_grad=True)

# %%
x
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
z1 = (x ** 2).sum() # x**2 -> 2 * x
z2 = (x ** 3).sum() # x**3 -> 3 * x**2

# %%
z1.backward()

# %%
x.grad
# Out:
# tensor([ 7., 20., 39.])

# %%
x.grad.zero_()
# Out:
# tensor([0., 0., 0.])

# %%
x.grad
# Out:
# tensor([0., 0., 0.])

# %%
z2.backward()

# %%
x.grad # [3, 12, 27]
# Out:
# tensor([ 3., 12., 27.])

# %%
x
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
y.detach().numpy()
# Out:
# array([1., 4., 9.], dtype=float32)

# %% [markdown]
# градиентный алгоритм минимизации функции (псевдокод)

# %%
def f(x):
    ...
    ...
    ...
    return z

alpha = 0.001
x = torch.randn(..., requires_grad=True)
for it in range(1000):
    z = f(x)
    z.backward()
    x = x - alpha * x.grad
    x.grad.zero_()

# %%
y.backward(torch.tensor([1,1.,1]))

# %%
z
# Out:
# tensor(14., grad_fn=<SumBackward0>)

# %%
z.item()
# Out:
# 14.0

# %%
y.detach().numpy()
# Out:
# array([1., 4., 9.], dtype=float32)

# %%
y.numpy()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-33-c7fe7d326412> in <module>()
# ----> 1 y.numpy()
#
# RuntimeError: Can't call numpy() on Variable that requires grad. Use var.detach().numpy() instead.

# %%
x = torch.tensor([1, 2, 3.], requires_grad=True)
z1 = (x**2).sum()
z2 = (x**3).sum()

# %%
z1.backward()

# %%
x.grad
# Out:
# tensor([2., 4., 6.])

# %%
x.grad.zero_()
z2.backward()

# %%
x.grad
# Out:
# tensor([ 3., 12., 27.])

# %%
x**2 -> 2 * x
x**3 -> 3 * x**2 == [3, 12, 27]
